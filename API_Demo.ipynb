# %%
from SpotifyAPIClient import *

# %%
client_id = '116037a141a04c628cdadaf11310f7d8'
client_secret = 'f505511e896d4b8fb4cd27c4e771f9f6'

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
play_data = spotify.search(query='work', search_type= 'playlist')
# Out:
# q=work&type=playlist

# %%
play_data
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=work&type=playlist&offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'My favorite Workout bangers 2020. Mostly Rap, mixed with some edm tracks :)',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/7AiuMp1D8Hli18nyTbriZ9'},
#     'href': 'https://api.spotify.com/v1/playlists/7AiuMp1D8Hli18nyTbriZ9',
#     'id': '7AiuMp1D8Hli18nyTbriZ9',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706c0000bebba8628f680b03e9f89d0f50c5',
#       'width': None}],
#     'name': 'Workout Playlist 2020 👊 💦',
#     'owner': {'display_name': 'metr',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/metrmusic'},
#      'href': 'https://api.spotify.com/v1/users/metrmusic',
#      'id': 'metrmusic',
#      'type': 'user',
#      'uri': 'spotify:user:metrmusic'},
#     'primary_color': None,
#     'public': None,
# ...

# %%
track_data = spotify.get_playlist_tracks('7AiuMp1D8Hli18nyTbriZ9')

# %%
track_data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/7AiuMp1D8Hli18nyTbriZ9/tracks?offset=0&limit=100',
#  'items': [{'added_at': '2020-07-08T22:41:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/metrmusic'},
#     'href': 'https://api.spotify.com/v1/users/metrmusic',
#     'id': 'metrmusic',
#     'type': 'user',
#     'uri': 'spotify:user:metrmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#        'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#        'id': '4kYSro6naA4h99UJvo89HB',
#        'name': 'Cardi B',
#        'type': 'artist',
#        'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}],
#      'available_markets': ['AD',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
# ...

# %%
import json

# %%
with open('track_dat.json', 'w') as json_file:
  json.dump(track_data, json_file)
